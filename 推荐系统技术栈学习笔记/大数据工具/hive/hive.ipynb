# %% [markdown]
# https://www.bilibili.com/video/BV1ek4y117Yq?p=156

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# hive与hadoop之间的关系

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# hive与传统数据库对比

# %% [markdown]
# ![image.png](attachment:image.png)
