# %% [markdown]
# 建立hdfs目录：`hadoop fs -mkdir -p /workspace/3.rs_project/project2/meiduo_mall`
#
# 建立以下sh文件mysqlToHDFS.sh，可将mysql中数据库meiduo_mall里指定表全部导入hdfs中：
# ```shell
# #!/bin/bash
# array=(tb_goods tb_goods_category tb_goods_specification tb_sku tb_sku_specification tb_specification_option)
#
# for table_name in ${array[@]};
# do
#     import sqoop \
#         --connect jbdc:mysql://hadoop-master/meiduo_mall \
#         --username root \
#         --password password \  # mysql数据库的密码
#         --table $table_name \  # 要读取数据库database中的表名
#         --m 5 \ #并行化是启动多个map task实现的，-m(或--num-mappers)参数指定map task数，默认是四个
#         --target-dir /project2-meiduo-rs/meiduo_mall/$table_name #指的是HDFS中导入表的存放目录(注意：是目录)
# done
#
# ```
# 执行：
# - ` chmod +x mysqlToHDFS.sh`
# - ` source mysqlToHDFS.sh`

# %% [markdown]
# #### 使用spark读取数据
# 注意默认情况下，导入数据，每列数据之间是用逗号分隔，因此可以如同csv文件一样进行读取

# %%
import os
# 配置pyspark和spark driver运行时 使用的python解释器
JAVA_HOME = '/root/bigdata/jdk'
PYSPARK_PYTHON = '/miniconda2/envs/py365/bin/python'
# 当存在多个版本时，不指定很可能会导致出错
os.environ['PYSPARK_PYTHON'] = PYSPARK_PYTHON
os.environ['PYSPARK_DRIVER_PYTHON'] = PYSPARK_PYTHON
os.environ['JAVA_HOME'] = JAVA_HOME
# 配置spark信息
from pyspark import SparkConf
from pyspark.sql import SparkSession

SPARK_APP_NAME = "TransferMySQLToHDFS"
SPARK_URL = "yarn"

conf = SparkConf()    # 创建spark config对象
config = (
	("spark.app.name", SPARK_APP_NAME),    # 设置启动的spark的app名称，没有提供，将随机产生一个名称
	("spark.executor.memory", "2g"),    # 设置该app启动时占用的内存用量，默认1g
	("spark.master", SPARK_URL),    # spark master的地址
    ("spark.executor.cores", "1"),    # 设置spark executor使用的CPU核心数
    ("spark.executor.instances", "1") # yarn时才会设置该项
)

conf.setAll(config)

# 利用config对象，创建spark session
spark = SparkSession.builder.config(conf=conf).enableHiveSupport().getOrCreate()

# %%
# ======跳过该cell，延申学习：使用saprk7077端口运行的配置=====
'''
conf = SparkConf()    # 创建spark config对象
config = (
	("spark.app.name", SPARK_APP_NAME),    # 设置启动的spark的app名称，没有提供，将随机产生一个名称
	("spark.executor.memory", "2g"),    # 设置该app启动时占用的内存用量，默认1g，指一台虚拟机
	("spark.master", SPARK_URL),    # spark master的地址
    ("spark.executor.cores", "2"),    # 设置spark executor使用的CPU核心数，指一台虚拟机
    # 以下三项配置，可以控制执行器数量
#     ("spark.dynamicAllocation.enabled", True),
#     ("spark.dynamicAllocation.initialExecutors", 1),    # 1个执行器
#     ("spark.shuffle.service.enabled", True)
# 	('spark.sql.pivotMaxValues', '99999'),  # 当需要pivot DF，且值很多时，需要修改，默认是10000
)
# 查看更详细配置及说明：https://spark.apache.org/docs/latest/configuration.html

conf.setAll(config)

# 利用config对象，创建spark session
spark = SparkSession.builder.config(conf=conf).getOrCreate()
'''

# %%
# !hadoop fs -ls /
# Out:
# Found 12 items
# drwxr-xr-x   - root supergroup          0 2020-11-06 10:24 /cate_count.csv
# drwxr-xr-x   - root supergroup          0 2020-12-12 19:23 /checkPoint
# drwxr-xr-x   - root supergroup          0 2020-12-12 18:39 /data
# drwxr-xr-x   - root supergroup          0 2020-12-11 11:11 /hbase
# drwxr-xr-x   - root supergroup          0 2020-11-11 21:33 /headlines
# -rw-r--r--   1 root supergroup       4358 2020-12-11 16:52 /iris.csv
# drwxr-xr-x   - root supergroup          0 2020-11-09 10:18 /meiduo_mall
# drwxr-xr-x   - root supergroup          0 2020-12-12 21:12 /models
# drwxr-xr-x   - root supergroup          0 2020-10-30 12:35 /output
# -rw-r--r--   1 root supergroup         84 2020-10-30 12:35 /test.txt
# drwx------   - root supergroup          0 2020-10-30 19:26 /tmp
# drwxr-xr-x   - root supergroup          0 2020-11-09 14:17 /user

# %%
ret = spark.read.csv('/meiduo_mall/tb_goods')
ret
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string, _c5: string, _c6: string, _c7: string, _c8: string, _c9: string, _c10: string, _c11: string, _c12: string]

# %%
ret.show()
ret.select('_c3','_c10').show(100)
# Out:
# +-----+--------------------+--------------------+--------------------+---+---+---+---+---+---+----+----+----+
# |  _c0|                 _c1|                 _c2|                 _c3|_c4|_c5|_c6|_c7|_c8|_c9|_c10|_c11|_c12|
# +-----+--------------------+--------------------+--------------------+---+---+---+---+---+---+----+----+----+
# |65233|2018-11-01 13:53:...|2018-11-01 13:53:...|万胶鼎 (整箱装多至72卷)透明胶...|  0|  0|  1|  5| 49|189|null|null|null|
# |65234|2018-11-01 13:53:...|2018-11-01 13:53:...|3M 思高1468 钛金属不粘剪刀...|  0|  0|  1|  5| 49|189|null|null|null|
# |65235|2018-11-01 13:53:...|2018-11-01 13:53:...|信发（TRNFA）农行定制 办公纸...|  0|  0|  1|  5| 49|189|null|null|null|
# |65236|2018-11-01 13:53:...|2018-11-01 13:53:...|斯图 （sitoo)布基胶带 地毯...|  0|  0|  1|  5| 49|189|null|null|null|
# |65237|2018-11-01 13:53:...|2018-11-01 13:53:...|齐心(COMIX) 省力按键式重型...|  0|  0|  1|  5| 49|189|null|null|null|
# |65238|2018-11-01 13:53:...|2018-11-01 13:53:...|红绿蓝 无线抢答器S100型抢答器...|  0|  0|  1|  5| 49|189|null|null|null|
# |65239|2018-11-01 13:53:...|2018-11-01 13:53:...|✅订书机 大号重型省力加厚订书机 ...|  0|  0|  1|  5| 49|189|null|null|null|
# |65240|2018-11-01 13:53:...|2018-11-01 13:53:...|ergo 6700瑞士进口鞋胶 软...|  0|  0|  1|  5| 49|189|null|null|null|
# |65241|2018-11-01 13:53:...|2018-11-01 13:53:...|步频（bupin） 无线抢答器MD...|  0|  0|  1|  5| 49|189|null|null|null|
# |65242|2018-11-01 13:53:...|2018-11-01 13:53:...|晨光（M&G）ABS92721 金...|  0|  0|  1|  5| 49|189|null|null|null|
# |65243|2018-11-01 13:53:...|2018-11-01 13:53:...|得力（deli） 隐形胶带可写字不...|  0|  0|  1|  5| 49|189|null|null|null|
# |65244|2018-11-01 13:53:...|2018-11-01 13:53:...|晨光(M&G)黑色金属网格圆形笔筒...|  0|  0|  1|  5| 49|189|null|null|null|
# |65245|2018-11-01 13:53:...|2018-11-01 13:53:...|信发（TRNFA）15g 韩国进口...|  0|  0|  1|  5| 49|189|null|null|null|
# |65246|2018-11-01 13:53:...|2018-11-01 13:53:...|三木(SUNWOOD) 1245 ...|  0|  0|  1|  5| 49|189|null|null|null|
# |65247|2018-11-01 13:53:...|2018-11-01 13:53:...|昕科桌面发热垫发热鼠标垫办公暖桌垫...|  0|  0|  1|  5| 49|189|null|null|null|
# |65248|2018-11-01 13:53:...|2018-11-01 13:53:...|得力（deli） 订书钉加厚大号厚...|  0|  0|  1|  5| 49|189|null|null|null|
# |65249|2018-11-01 13:53:...|2018-11-01 13:53:...|U 牌透明胶带 封口胶带 封箱胶带...|  0|  0|  1|  5| 49|189|null|null|null|
# |65250|2018-11-01 13:53:...|2018-11-01 13:53:...|欣乐 A4复印纸a470g80g打...|  0|  0|  1|  5| 49|189|null|null|null|
# |65251|2018-11-01 13:53:...|2018-11-01 13:53:...|得力(deli)12支15gPVA...|  0|  0|  1|  5| 49|189|null|null|null|
# |65252|2018-11-01 13:53:...|2018-11-01 13:53:...|齐心(COMIX) 60只装15m...|  0|  0|  1|  5| 49|189|null|null|null|
# +-----+--------------------+--------------------+--------------------+---+---+---+---+---+---+----+----+----+
# only showing top 20 rows
#
# +--------------------+----+
# |                 _c3|_c10|
# +--------------------+----+
# |万胶鼎 (整箱装多至72卷)透明胶...|null|
# |3M 思高1468 钛金属不粘剪刀...|null|
# |信发（TRNFA）农行定制 办公纸...|null|
# |斯图 （sitoo)布基胶带 地毯...|null|
# |齐心(COMIX) 省力按键式重型...|null|
# |红绿蓝 无线抢答器S100型抢答器...|null|
# |✅订书机 大号重型省力加厚订书机 ...|null|
# |ergo 6700瑞士进口鞋胶 软...|null|
# |步频（bupin） 无线抢答器MD...|null|
# |晨光（M&G）ABS92721 金...|null|
# |得力（deli） 隐形胶带可写字不...|null|
# |晨光(M&G)黑色金属网格圆形笔筒...|null|
# |信发（TRNFA）15g 韩国进口...|null|
# |三木(SUNWOOD) 1245 ...|null|
# |昕科桌面发热垫发热鼠标垫办公暖桌垫...|null|
# |得力（deli） 订书钉加厚大号厚...|null|
# |U 牌透明胶带 封口胶带 封箱胶带...|null|
# |欣乐 A4复印纸a470g80g打...|null|
# |得力(deli)12支15gPVA...|null|
# |齐心(COMIX) 60只装15m...|null|
# |日本国誉(KOKUYO)高透明办公...|null|
# |得力（deli） 得力文具套装 9...|null|
# |日本国誉(KOKUYO)可替换式 ...|null|
# |杉丹（shandan） 中药防蛀防...|null|
# |齐心(Comix) 全包胶7.5m...|null|
# |斯图sitoo 党徽胸章磁扣别针党...|null|
# |凌美（LAMY） 德国原装进口凌美...|null|
# |得力(deli)A3磁性展示贴 营...|null|
# |斯图 2018-2019年台历韩式...|null|
# |得力(deli)1.2L不锈钢电热...|null|
# |得力(deli)大屏幕多功能夜光数...|null|
# |步频（bupin） 320LS无线...|null|
# |广博(GuangBo)210页重型...|null|
# |金隆兴(Glosen) 便民服务箱...|null|
# |海医（Hey Model） 豪华版...|null|
# |日本进口国誉(KOKUYO)FLA...|null|
# |得力（deli） 固体胶 胶棒 1...|null|
# |频跃（pansyue） 无线抢答器...|null|
# |探戈（TANGO）笔筒金属镂空网纹...|null|
# |得力(deli)办公桌面装订组合套...|null|
# |✅得力（deli）大号订书机 钉书...|null|
# |齐心（COMIX）3把装170mm...|null|
# |优和（UHOO） 6712 糖果色...|null|
# |得力(deli)Ф285mm(11...|null|
# |北极熊（Polar bear） L...|null|
# |优必利 大号落地式1000位500...|null|
# |金隆兴（Glosen）木质笔筒办公...|null|
# |英雄实业授权 永生636三件套铱金...|null|
# |艾文格（AWG） 包邮亚克力强磁台...|null|
# |三木(SUNWOOD) 6403 ...|null|
# |得力(deli)Ф20cm金属底座...|null|
# |马培德（Maped） 丝滑炫彩棒小...|null|
# |金隆兴(Glosen)医药箱家用多...|null|
# |得力（deli） 7103 固体胶...|null|
# |晨光（M&G）ABS92710彩色...|null|
# |得力(deli)锁水不锈钢内胆电热...|null|
# |信发（TRNFA）MS-75 利百...|null|
# |George Willsons 可...|null|
# |九麟 液晶显示屏 密码钥匙箱 钥匙...|null|
# |透明胶带封箱带大卷打包封口胶带纸宽...|null|
# |得力（deli） 8903 金属多...|null|
# |得力(deli)21g强粘性pvp...|null|
# |初心木质万年历笔筒创意办公用品文具...|null|
# |得力(deli)经久耐用1号国旗/...|null|
# |晨光（M&G）重型订书机200页A...|null|
# |得力(deli)多功能57合一精密...|null|
# |广博(GuangBo)10盒装29...|null|
# |晨光(M&G)便携名片盒单个装 黑...|null|
# |3M 思高 2包装 R101 水晶...|null|
# |科记文具（KEJEA） 名片座多层...|null|
# |齐心(Comix) 稳固金属文件柜...|null|
# |日本旗牌(Shachihata)办...|null|
# |得力(deli)5张便携皮质发票夹...|null|
# |得力（deli）7505 打价机标...|null|
# |得力(deli) 直径25cm双面...|null|
# |得力(deli)36g高粘度PVP...|null|
# |得力(deli)40只19mm微笑...|null|
# |广博(GuangBo)6卷装48m...|null|
# |得力（deli） 电脑暖手桌面发热...|null|
# |广博(GuangBo)12号旋转型...|null|
# |绍泽文化 大号可伸缩铁架书立蓝色鲸...|null|
# |北极熊（Polar bear） W...|null|
# |欧标（MATE-IST）透明胶带6...|null|
# |格力（GREE）品圆 大1匹 定速...|null|
# |广博(GuangBo)30只*3卷...|null|
# |步频（bupin） 无线抢答器70...|null|
# |广博(GuangBo)6卷装60m...|null|
# |信发（TRNFA）银行眼镜（10副...|null|
# |金隆兴（Glosen） B088 ...|null|
# |得力（deli） 自动号码机 手动...|null|
# |得力(deli)26/6省力订书钉...|null|
# |AUCS 电子荧光板一体支架式 L...|null|
# |三木(SUNWOOD) 8102 ...|null|
# |得力(deli)210页省力型厚层...|null|
# |得力(deli)48mm*60y(...|null|
# |北极熊（Polar bear） M...|null|
# |得力(deli)10位耐用双排标价...|null|
# |ergo 1309瑞士进口强力ab...|null|
# |晨光(M&G)21g高粘度固体胶棒...|null|
# |信发（TRNFA）PJ-2145 ...|null|
# +--------------------+----+
# only showing top 100 rows
