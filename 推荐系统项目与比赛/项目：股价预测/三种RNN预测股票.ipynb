# %% [markdown]
# # 预测茅台股票日k线开盘价
#
# ### 时间：2010-4-26到2020-4-26

# %% [markdown]
# - #### SimpleRNN
#     - 均方误差: 4064.275347
#     - 均方根误差: 63.751669
#     - 平均绝对误差: 59.360274
# - #### LSTM
#     - 均方误差: 3084.904418
#     - 均方根误差: 55.541916
#     - 平均绝对误差: 49.045534
# - #### GRU
#     - 均方误差: 1743.493806
#     - 均方根误差: 41.755165
#     - 平均绝对误差: 36.362571

# %%
# 获取k线数据
import tushare as ts
import matplotlib.pyplot as plt

# D=日k线
df1 = ts.get_k_data('600519', ktype='D', start='2010-04-26', end='2020-04-26')
df1
# datapath1 = "./SH600519.csv"
# df1.to_csv(datapath1)
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://waditu.com/document/2
#             date      open     close      high       low     volume    code
# 74    2010-04-26    88.702    87.381    89.072    87.362  107036.13  600519
# 75    2010-04-27    87.355    84.841    87.355    84.681   58234.48  600519
# 76    2010-04-28    84.235    84.318    85.128    83.597   26287.43  600519
# 77    2010-04-29    84.592    85.671    86.315    84.592   34501.20  600519
# 78    2010-04-30    83.871    82.340    83.871    81.523   85566.70  600519
# ...          ...       ...       ...       ...       ...        ...     ...
# 2495  2020-04-20  1221.000  1227.300  1231.500  1216.800   24239.00  600519
# 2496  2020-04-21  1221.020  1200.000  1223.990  1193.000   29224.00  600519
# 2497  2020-04-22  1206.000  1244.500  1249.500  1202.220   44035.00  600519
# 2498  2020-04-23  1250.000  1252.260  1265.680  1247.770   26899.00  600519
# 2499  2020-04-24  1248.000  1250.560  1259.890  1235.180   19122.00  600519
#
# [2426 rows x 7 columns]

# %% [markdown]
# ## 1. SimpleRNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, LSTM, SimpleRNN
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, LSTM, SimpleRNN
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

maotai = pd.read_csv('./SH600519.csv')  # 读取股票文件

training_set = maotai.iloc[0:2426 - 300, 2:3].values  
# 前(2426-300=2126)天的开盘价作为训练集,表格从0开始计数，
# 2:3 是提取[2:3)列，前闭后开,故提取出C列开盘价
test_set = maotai.iloc[2426 - 300:, 2:3].values  # 后300天的开盘价作为测试集

# 归一化
sc = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
training_set_scaled = sc.fit_transform(training_set)  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
test_set = sc.transform(test_set)  # 利用训练集的属性对测试集进行归一化

x_train = []
y_train = []

x_test = []
y_test = []

# 测试集：csv表格中前2426-300=2126天数据
# 利用for循环，遍历整个训练集，提取训练集中连续60天的开盘价作为输入特征x_train，第61天的数据作为标签，for循环共构建2426-300-60=2066组数据。
for i in range(60, len(training_set_scaled)):
    x_train.append(training_set_scaled[i - 60:i, 0])
    y_train.append(training_set_scaled[i, 0])
# 对训练集进行打乱
np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
tf.random.set_seed(7)
# 将训练集由list格式变为array格式
x_train, y_train = np.array(x_train), np.array(y_train)

# 使x_train符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]。
# 此处整个数据集送入，送入样本数为x_train.shape[0]即2066组数据；
# 输入60个开盘价，预测出第61天的开盘价，循环核时间展开步数为60; 
# 每个时间步送入的特征是某一天的开盘价，只有1个数据，故每个时间步输入特征个数为1
x_train = np.reshape(x_train, (x_train.shape[0], 60, 1))
# 测试集：csv表格中后300天数据
# 利用for循环，遍历整个测试集，提取测试集中连续60天的开盘价作为输入特征x_test，第61天的数据作为标签，for循环共构建300-60=240组数据。
for i in range(60, len(test_set)):
    x_test.append(test_set[i - 60:i, 0])
    y_test.append(test_set[i, 0])
# 测试集变array并reshape为符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], 60, 1))

model = tf.keras.Sequential([
    # 一般最后一层的循环核用False，仅在最后一个时间步输出ht(默认)；中间的层循环核用True，每个时间步都把ht输出给下一层。
    SimpleRNN(80, return_sequences=True),# 80个记忆体的循环核
    Dropout(0.2),
    SimpleRNN(100),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='mean_squared_error')  # 损失函数用均方误差
# 该应用只观测loss数值，不观测准确率，所以删去metrics选项，一会在每个epoch迭代显示时只显示loss值

checkpoint_save_path = "./checkpoint/SimpleRNN_stock.ckpt"

if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model-----------------')
    model.load_weights(checkpoint_save_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,#只保留模型参数
                                                 save_best_only=True,# 只保留最优结果
                                                 monitor='val_loss')

history = model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])#validation_freq 每多少次epoch迭代使用测试集验证一次结果

model.summary()

file = open('./SimpleRNN_weights.txt', 'w')  # 参数提取
for v in model.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

################## predict ######################
# 测试集输入模型进行预测
predicted_stock_price = model.predict(x_test)
# 对预测数据还原---从（0，1）反归一化到原始范围
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# 对真实数据还原---从（0，1）反归一化到原始范围
real_stock_price = sc.inverse_transform(test_set[60:])
# 画出真实数据和预测数据的对比曲线
plt.plot(real_stock_price, color='red', label='MaoTai Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted MaoTai Stock Price')
plt.title('MaoTai Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('MaoTai Stock Price')
plt.legend()
plt.show()

##########evaluate##############
# calculate MSE 均方误差 ---> E[(预测值-真实值)^2] (预测值减真实值求平方后求均值)
mse = mean_squared_error(predicted_stock_price, real_stock_price)
# calculate RMSE 均方根误差--->sqrt[MSE]    (对均方误差开方)
rmse = math.sqrt(mean_squared_error(predicted_stock_price, real_stock_price))
# calculate MAE 平均绝对误差----->E[|预测值-真实值|](预测值减真实值求绝对值后求均值）
mae = mean_absolute_error(predicted_stock_price, real_stock_price)
print('均方误差: %.6f' % mse)
print('均方根误差: %.6f' % rmse)
print('平均绝对误差: %.6f' % mae)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 2s 23ms/step - loss: 0.2396 - val_loss: 0.0434
# Epoch 2/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0311 - val_loss: 0.0044
# Epoch 3/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0155 - val_loss: 0.0036
# Epoch 4/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0115 - val_loss: 0.0131
# Epoch 5/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0077 - val_loss: 0.0082
# Epoch 6/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0079 - val_loss: 0.0026
# Epoch 7/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0073 - val_loss: 0.0187
# Epoch 8/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0061 - val_loss: 0.0033
# Epoch 9/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0050 - val_loss: 0.0113
# Epoch 10/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0051 - val_loss: 0.0035
# Epoch 11/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0039 - val_loss: 0.0049
# Epoch 12/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0035 - val_loss: 0.0208
# Epoch 13/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0049 - val_loss: 0.0052
# Epoch 14/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0035 - val_loss: 0.0079
# Epoch 15/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0031 - val_loss: 0.0021
# Epoch 16/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 17/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0032 - val_loss: 0.0019
# Epoch 18/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 19/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0027 - val_loss: 0.0031
# Epoch 20/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 21/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0023 - val_loss: 0.0058
# Epoch 22/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0026 - val_loss: 0.0013
# Epoch 23/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0021 - val_loss: 0.0083
# Epoch 24/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 25/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0025 - val_loss: 0.0018
# Epoch 26/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 27/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0021 - val_loss: 0.0100
# Epoch 28/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 0.0067
# Epoch 29/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0019 - val_loss: 0.0050
# Epoch 30/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 0.0097
# Epoch 31/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0014 - val_loss: 0.0046
# Epoch 32/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 33/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0059
# Epoch 34/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 35/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 36/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 0.0137
# Epoch 37/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0020 - val_loss: 0.0051
# Epoch 38/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 39/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 40/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 41/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 42/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0067
# Epoch 43/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0059
# Epoch 44/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 45/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 46/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 47/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0013 - val_loss: 0.0098
# Epoch 48/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 49/50
# 33/33 [==============================] - 1s 18ms/step - loss: 0.0012 - val_loss: 0.0042
# Epoch 50/50
# 33/33 [==============================] - 1s 17ms/step - loss: 0.0011 - val_loss: 0.0081
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_12 (SimpleRNN)    (None, 60, 80)            6560
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 60, 80)            0
# _________________________________________________________________
# simple_rnn_13 (SimpleRNN)    (None, 100)               18100
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 24,761
# Trainable params: 24,761
# Non-trainable params: 0
# _________________________________________________________________
# 均方误差: 4064.275347
# 均方根误差: 63.751669
# 平均绝对误差: 59.360274

# %% [markdown]
# ## 2. LSTM

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, LSTM
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

maotai = pd.read_csv('./SH600519.csv')  # 读取股票文件

training_set = maotai.iloc[0:2426 - 300, 2:3].values  
# 前(2426-300=2126)天的开盘价作为训练集,表格从0开始计数，
# 2:3 是提取[2:3)列，前闭后开,故提取出C列开盘价
test_set = maotai.iloc[2426 - 300:, 2:3].values  # 后300天的开盘价作为测试集

# 归一化
sc = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
training_set_scaled = sc.fit_transform(training_set)  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
test_set = sc.transform(test_set)  # 利用训练集的属性对测试集进行归一化

x_train = []
y_train = []

x_test = []
y_test = []

# 测试集：csv表格中前2426-300=2126天数据
# 利用for循环，遍历整个训练集，提取训练集中连续60天的开盘价作为输入特征x_train，第61天的数据作为标签，for循环共构建2426-300-60=2066组数据。
for i in range(60, len(training_set_scaled)):
    x_train.append(training_set_scaled[i - 60:i, 0])
    y_train.append(training_set_scaled[i, 0])
# 对训练集进行打乱
np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
tf.random.set_seed(7)
# 将训练集由list格式变为array格式
x_train, y_train = np.array(x_train), np.array(y_train)

# 使x_train符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]。
# 此处整个数据集送入，送入样本数为x_train.shape[0]即2066组数据；输入60个开盘价，预测出第61天的开盘价，循环核时间展开步数为60; 每个时间步送入的特征是某一天的开盘价，只有1个数据，故每个时间步输入特征个数为1
x_train = np.reshape(x_train, (x_train.shape[0], 60, 1))
# 测试集：csv表格中后300天数据
# 利用for循环，遍历整个测试集，提取测试集中连续60天的开盘价作为输入特征x_train，第61天的数据作为标签，for循环共构建300-60=240组数据。
for i in range(60, len(test_set)):
    x_test.append(test_set[i - 60:i, 0])
    y_test.append(test_set[i, 0])
# 测试集变array并reshape为符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], 60, 1))

model = tf.keras.Sequential([
    LSTM(80, return_sequences=True),
    Dropout(0.2),
    LSTM(100),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='mean_squared_error')  # 损失函数用均方误差
# 该应用只观测loss数值，不观测准确率，所以删去metrics选项，一会在每个epoch迭代显示时只显示loss值

checkpoint_save_path = "./checkpoint/LSTM_stock.ckpt"

if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model-----------------')
    model.load_weights(checkpoint_save_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor='val_loss')

history = model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])

model.summary()

file = open('./LSTM_weights.txt', 'w')  # 参数提取
for v in model.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

################## predict ######################
# 测试集输入模型进行预测
predicted_stock_price = model.predict(x_test)
# 对预测数据还原---从（0，1）反归一化到原始范围
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# 对真实数据还原---从（0，1）反归一化到原始范围
real_stock_price = sc.inverse_transform(test_set[60:])
# 画出真实数据和预测数据的对比曲线
plt.plot(real_stock_price, color='red', label='MaoTai Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted MaoTai Stock Price')
plt.title('MaoTai Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('MaoTai Stock Price')
plt.legend()
plt.show()

##########evaluate##############
# calculate MSE 均方误差 ---> E[(预测值-真实值)^2] (预测值减真实值求平方后求均值)
mse = mean_squared_error(predicted_stock_price, real_stock_price)
# calculate RMSE 均方根误差--->sqrt[MSE]    (对均方误差开方)
rmse = math.sqrt(mean_squared_error(predicted_stock_price, real_stock_price))
# calculate MAE 平均绝对误差----->E[|预测值-真实值|](预测值减真实值求绝对值后求均值）
mae = mean_absolute_error(predicted_stock_price, real_stock_price)
print('均方误差: %.6f' % mse)
print('均方根误差: %.6f' % rmse)
print('平均绝对误差: %.6f' % mae)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 4s 58ms/step - loss: 0.0331 - val_loss: 0.0493
# Epoch 2/50
# 33/33 [==============================] - 2s 45ms/step - loss: 0.0016 - val_loss: 0.0140
# Epoch 3/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0011 - val_loss: 0.0070
# Epoch 4/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0012 - val_loss: 0.0204
# Epoch 5/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0011 - val_loss: 0.0066
# Epoch 6/50
# 33/33 [==============================] - 2s 47ms/step - loss: 9.9358e-04 - val_loss: 0.0061
# Epoch 7/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0012 - val_loss: 0.0048
# Epoch 8/50
# 33/33 [==============================] - 2s 47ms/step - loss: 9.6675e-04 - val_loss: 0.0129
# Epoch 9/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0011 - val_loss: 0.0157
# Epoch 10/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0011 - val_loss: 0.0161
# Epoch 11/50
# 33/33 [==============================] - 2s 47ms/step - loss: 9.0224e-04 - val_loss: 0.0042
# Epoch 12/50
# 33/33 [==============================] - 2s 47ms/step - loss: 8.0339e-04 - val_loss: 0.0042
# Epoch 13/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0012 - val_loss: 0.0090
# Epoch 14/50
# 33/33 [==============================] - 2s 47ms/step - loss: 9.5860e-04 - val_loss: 0.0118
# Epoch 15/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0011 - val_loss: 0.0158
# Epoch 16/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0010 - val_loss: 0.0097
# Epoch 17/50
# 33/33 [==============================] - 2s 47ms/step - loss: 9.1450e-04 - val_loss: 0.0132
# Epoch 18/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0010 - val_loss: 0.0064
# Epoch 19/50
# 33/33 [==============================] - 2s 47ms/step - loss: 6.0981e-04 - val_loss: 0.0145
# Epoch 20/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0012 - val_loss: 0.0087
# Epoch 21/50
# 33/33 [==============================] - 2s 47ms/step - loss: 8.5185e-04 - val_loss: 0.0091
# Epoch 22/50
# 33/33 [==============================] - 2s 47ms/step - loss: 9.5090e-04 - val_loss: 0.0024
# Epoch 23/50
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0010 - val_loss: 0.0024
# Epoch 24/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.7069e-04 - val_loss: 0.0125
# Epoch 25/50
# 33/33 [==============================] - 2s 48ms/step - loss: 8.5911e-04 - val_loss: 0.0101
# Epoch 26/50
# 33/33 [==============================] - 2s 47ms/step - loss: 7.4808e-04 - val_loss: 0.0054
# Epoch 27/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.2909e-04 - val_loss: 0.0242
# Epoch 28/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.9517e-04 - val_loss: 0.0039
# Epoch 29/50
# 33/33 [==============================] - 2s 53ms/step - loss: 7.4188e-04 - val_loss: 0.0063
# Epoch 30/50
# 33/33 [==============================] - 2s 50ms/step - loss: 6.7359e-04 - val_loss: 0.0104
# Epoch 31/50
# 33/33 [==============================] - 2s 50ms/step - loss: 6.9387e-04 - val_loss: 0.0037
# Epoch 32/50
# 33/33 [==============================] - 2s 50ms/step - loss: 7.3625e-04 - val_loss: 0.0070
# Epoch 33/50
# 33/33 [==============================] - 2s 50ms/step - loss: 6.0647e-04 - val_loss: 0.0174
# Epoch 34/50
# 33/33 [==============================] - 2s 50ms/step - loss: 8.2490e-04 - val_loss: 0.0105
# Epoch 35/50
# 33/33 [==============================] - 2s 50ms/step - loss: 6.9937e-04 - val_loss: 0.0047
# Epoch 36/50
# 33/33 [==============================] - 2s 50ms/step - loss: 7.5440e-04 - val_loss: 0.0121
# Epoch 37/50
# 33/33 [==============================] - 2s 50ms/step - loss: 8.5163e-04 - val_loss: 0.0029
# Epoch 38/50
# 33/33 [==============================] - 2s 50ms/step - loss: 8.2813e-04 - val_loss: 0.0036
# Epoch 39/50
# 33/33 [==============================] - 2s 50ms/step - loss: 5.9563e-04 - val_loss: 0.0174
# Epoch 40/50
# 33/33 [==============================] - 2s 50ms/step - loss: 6.6393e-04 - val_loss: 0.0091
# Epoch 41/50
# 33/33 [==============================] - 2s 50ms/step - loss: 6.1002e-04 - val_loss: 0.0054
# Epoch 42/50
# 33/33 [==============================] - 2s 50ms/step - loss: 5.3554e-04 - val_loss: 0.0086
# Epoch 43/50
# 33/33 [==============================] - 2s 50ms/step - loss: 6.5780e-04 - val_loss: 0.0067
# Epoch 44/50
# 33/33 [==============================] - 2s 50ms/step - loss: 6.8702e-04 - val_loss: 0.0021
# Epoch 45/50
# 33/33 [==============================] - 2s 50ms/step - loss: 7.3856e-04 - val_loss: 0.0035
# Epoch 46/50
# 33/33 [==============================] - 2s 51ms/step - loss: 5.1685e-04 - val_loss: 0.0091
# Epoch 47/50
# 33/33 [==============================] - 2s 51ms/step - loss: 7.3591e-04 - val_loss: 0.0125
# Epoch 48/50
# 33/33 [==============================] - 2s 50ms/step - loss: 7.6820e-04 - val_loss: 0.0042
# Epoch 49/50
# 33/33 [==============================] - 2s 50ms/step - loss: 6.4222e-04 - val_loss: 0.0059
# Epoch 50/50
# 33/33 [==============================] - 2s 50ms/step - loss: 5.9981e-04 - val_loss: 0.0061
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_30 (LSTM)               (None, 60, 80)            26240
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 60, 80)            0
# _________________________________________________________________
# lstm_31 (LSTM)               (None, 100)               72400
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 98,741
# Trainable params: 98,741
# Non-trainable params: 0
# _________________________________________________________________
# 均方误差: 3084.904418
# 均方根误差: 55.541916
# 平均绝对误差: 49.045534

# %% [markdown]
# ## 3. GRU

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, GRU
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math

maotai = pd.read_csv('./SH600519.csv')  # 读取股票文件

training_set = maotai.iloc[0:2426 - 300, 2:3].values  # 前(2426-300=2126)天的开盘价作为训练集,表格从0开始计数，2:3 是提取[2:3)列，前闭后开,故提取出C列开盘价
test_set = maotai.iloc[2426 - 300:, 2:3].values  # 后300天的开盘价作为测试集

# 归一化
sc = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
training_set_scaled = sc.fit_transform(training_set)  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
test_set = sc.transform(test_set)  # 利用训练集的属性对测试集进行归一化

x_train = []
y_train = []

x_test = []
y_test = []

# 测试集：csv表格中前2426-300=2126天数据
# 利用for循环，遍历整个训练集，提取训练集中连续60天的开盘价作为输入特征x_train，第61天的数据作为标签，for循环共构建2426-300-60=2066组数据。
for i in range(60, len(training_set_scaled)):
    x_train.append(training_set_scaled[i - 60:i, 0])
    y_train.append(training_set_scaled[i, 0])
# 对训练集进行打乱
np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
tf.random.set_seed(7)
# 将训练集由list格式变为array格式
x_train, y_train = np.array(x_train), np.array(y_train)

# 使x_train符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]。
# 此处整个数据集送入，送入样本数为x_train.shape[0]即2066组数据；输入60个开盘价，预测出第61天的开盘价，循环核时间展开步数为60; 每个时间步送入的特征是某一天的开盘价，只有1个数据，故每个时间步输入特征个数为1
x_train = np.reshape(x_train, (x_train.shape[0], 60, 1))
# 测试集：csv表格中后300天数据
# 利用for循环，遍历整个测试集，提取测试集中连续60天的开盘价作为输入特征x_train，第61天的数据作为标签，for循环共构建300-60=240组数据。
for i in range(60, len(test_set)):
    x_test.append(test_set[i - 60:i, 0])
    y_test.append(test_set[i, 0])
# 测试集变array并reshape为符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], 60, 1))

model = tf.keras.Sequential([
    GRU(80, return_sequences=True),
    Dropout(0.2),
    GRU(100),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='mean_squared_error')  # 损失函数用均方误差
# 该应用只观测loss数值，不观测准确率，所以删去metrics选项，一会在每个epoch迭代显示时只显示loss值

checkpoint_save_path = "./checkpoint/GRU_stock.ckpt"

if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model-----------------')
    model.load_weights(checkpoint_save_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor='val_loss')

history = model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])

model.summary()

file = open('./GRU_weights.txt', 'w')  # 参数提取
for v in model.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

################## predict ######################
# 测试集输入模型进行预测
predicted_stock_price = model.predict(x_test)
# 对预测数据还原---从（0，1）反归一化到原始范围
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# 对真实数据还原---从（0，1）反归一化到原始范围
real_stock_price = sc.inverse_transform(test_set[60:])
# 画出真实数据和预测数据的对比曲线
plt.plot(real_stock_price, color='red', label='MaoTai Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted MaoTai Stock Price')
plt.title('MaoTai Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('MaoTai Stock Price')
plt.legend()
plt.show()

##########evaluate##############
# calculate MSE 均方误差 ---> E[(预测值-真实值)^2] (预测值减真实值求平方后求均值)
mse = mean_squared_error(predicted_stock_price, real_stock_price)
# calculate RMSE 均方根误差--->sqrt[MSE]    (对均方误差开方)
rmse = math.sqrt(mean_squared_error(predicted_stock_price, real_stock_price))
# calculate MAE 平均绝对误差----->E[|预测值-真实值|](预测值减真实值求绝对值后求均值）
mae = mean_absolute_error(predicted_stock_price, real_stock_price)
print('均方误差: %.6f' % mse)
print('均方根误差: %.6f' % rmse)
print('平均绝对误差: %.6f' % mae)
# Out:
# Epoch 1/50
# 33/33 [==============================] - 3s 52ms/step - loss: 0.0467 - val_loss: 0.0133
# Epoch 2/50
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0018 - val_loss: 0.0044
# Epoch 3/50
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0012 - val_loss: 0.0029
# Epoch 4/50
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0010 - val_loss: 0.0027
# Epoch 5/50
# 33/33 [==============================] - 2s 49ms/step - loss: 9.9816e-04 - val_loss: 0.0016
# Epoch 6/50
# 33/33 [==============================] - 2s 49ms/step - loss: 8.6051e-04 - val_loss: 0.0023
# Epoch 7/50
# 33/33 [==============================] - 2s 48ms/step - loss: 9.2776e-04 - val_loss: 0.0015
# Epoch 8/50
# 33/33 [==============================] - 2s 48ms/step - loss: 8.9080e-04 - val_loss: 0.0034
# Epoch 9/50
# 33/33 [==============================] - 2s 49ms/step - loss: 9.5172e-04 - val_loss: 0.0020
# Epoch 10/50
# 33/33 [==============================] - 2s 50ms/step - loss: 9.0934e-04 - val_loss: 0.0015
# Epoch 11/50
# 33/33 [==============================] - 2s 49ms/step - loss: 6.6255e-04 - val_loss: 0.0015
# Epoch 12/50
# 33/33 [==============================] - 2s 49ms/step - loss: 8.5593e-04 - val_loss: 0.0023
# Epoch 13/50
# 33/33 [==============================] - 2s 49ms/step - loss: 9.5506e-04 - val_loss: 0.0020
# Epoch 14/50
# 33/33 [==============================] - 2s 48ms/step - loss: 8.1832e-04 - val_loss: 0.0015
# Epoch 15/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.9905e-04 - val_loss: 0.0044
# Epoch 16/50
# 33/33 [==============================] - 2s 48ms/step - loss: 9.5335e-04 - val_loss: 0.0015
# Epoch 17/50
# 33/33 [==============================] - 2s 48ms/step - loss: 8.4285e-04 - val_loss: 0.0020
# Epoch 18/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.9402e-04 - val_loss: 0.0019
# Epoch 19/50
# 33/33 [==============================] - 2s 48ms/step - loss: 5.6395e-04 - val_loss: 0.0045
# Epoch 20/50
# 33/33 [==============================] - 2s 48ms/step - loss: 9.9822e-04 - val_loss: 0.0020
# Epoch 21/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.1459e-04 - val_loss: 0.0020
# Epoch 22/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.3224e-04 - val_loss: 0.0023
# Epoch 23/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.7394e-04 - val_loss: 0.0017
# Epoch 24/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.8574e-04 - val_loss: 0.0065
# Epoch 25/50
# 33/33 [==============================] - 2s 48ms/step - loss: 8.0550e-04 - val_loss: 0.0028
# Epoch 26/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.2837e-04 - val_loss: 0.0016
# Epoch 27/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.7594e-04 - val_loss: 0.0099
# Epoch 28/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.0385e-04 - val_loss: 0.0021
# Epoch 29/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.4804e-04 - val_loss: 0.0030
# Epoch 30/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.3601e-04 - val_loss: 0.0052
# Epoch 31/50
# 33/33 [==============================] - 2s 48ms/step - loss: 5.9648e-04 - val_loss: 0.0014
# Epoch 32/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.1301e-04 - val_loss: 0.0023
# Epoch 33/50
# 33/33 [==============================] - 2s 48ms/step - loss: 5.4795e-04 - val_loss: 0.0074
# Epoch 34/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.7912e-04 - val_loss: 0.0032
# Epoch 35/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.5383e-04 - val_loss: 0.0022
# Epoch 36/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.4823e-04 - val_loss: 0.0082
# Epoch 37/50
# 33/33 [==============================] - 2s 48ms/step - loss: 7.6994e-04 - val_loss: 0.0014
# Epoch 38/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.6200e-04 - val_loss: 0.0015
# Epoch 39/50
# 33/33 [==============================] - 2s 48ms/step - loss: 5.2588e-04 - val_loss: 0.0090
# Epoch 40/50
# 33/33 [==============================] - 2s 48ms/step - loss: 5.6395e-04 - val_loss: 0.0035
# Epoch 41/50
# 33/33 [==============================] - 2s 48ms/step - loss: 5.6929e-04 - val_loss: 0.0014
# Epoch 42/50
# 33/33 [==============================] - 2s 48ms/step - loss: 4.8285e-04 - val_loss: 0.0020
# Epoch 43/50
# 33/33 [==============================] - 2s 48ms/step - loss: 5.9649e-04 - val_loss: 0.0024
# Epoch 44/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.3154e-04 - val_loss: 0.0020
# Epoch 45/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.8982e-04 - val_loss: 0.0013
# Epoch 46/50
# 33/33 [==============================] - 2s 49ms/step - loss: 4.6145e-04 - val_loss: 0.0020
# Epoch 47/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.6510e-04 - val_loss: 0.0037
# Epoch 48/50
# 33/33 [==============================] - 2s 48ms/step - loss: 6.5047e-04 - val_loss: 0.0014
# Epoch 49/50
# 33/33 [==============================] - 2s 48ms/step - loss: 5.5952e-04 - val_loss: 0.0021
# Epoch 50/50
# 33/33 [==============================] - 2s 49ms/step - loss: 5.4244e-04 - val_loss: 0.0035
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_4 (GRU)                  (None, 60, 80)            19920
# _________________________________________________________________
# dropout_50 (Dropout)         (None, 60, 80)            0
# _________________________________________________________________
# gru_5 (GRU)                  (None, 100)               54600
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 74,621
# Trainable params: 74,621
# Non-trainable params: 0
# _________________________________________________________________
# 均方误差: 1743.493806
# 均方根误差: 41.755165
# 平均绝对误差: 36.362571
