# %% [markdown]
# https://www.bilibili.com/video/BV1ek4y117Yq?p=74

# %% [markdown]
# ### 1.设计流程

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 了解mapreduce的计算框架
# <br>![image.png](attachment:image.png)

# %% [markdown]
# ### 2.编程规范

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.案例1---wordcount

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.mapreduce分区

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5.mapreduce的排序与序列化

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6.规约combiner

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7.案例2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
